# %%
import os, sys, importlib
import copy
sys.path.append('/content/drive/My Drive/Research/qutip_sim/custom_files')
sys.path.append('/content/drive/My Drive/Research/qutip_sim/custom_files/VQE_files')
sys.path.append('/content/drive/My Drive/Research/qutip_sim/site-packages')
sys.path.append('/content/drive/My Drive/Research/qutip_sim/site-packages/qutip')
from H2Functions import read_in_data
from qutip import *
# !pip install scikit-optimize
from analysis_tools import *
from sim_functions import *
from experiment_sim import *

import matplotlib.pyplot as plt
import numpy as np
from scipy import optimize
# %load_ext autoreload 
# %autoreload 2
label = ["II", "IX", "IY", "IZ", "XI", "XX", "XY", "XZ", "YI", "YX", "YY", "YZ", "ZI", "ZX", "ZY", "ZZ"]
# Out:
# ...
#      |████████████████████████████████| 102kB 4.2MB/s
# ...

# %% [markdown]
# # Test

# %%
directory1 = '/content/drive/My Drive/Research/Data/Experiment/VQE/VQE_2018/Jun18'
errors = (np.array([1.,2.,4.])*1040. + 480.) / 1520.
a = list(range(34,71,2))
b = list(range(83,122,2))
c = list(range(83,122,2))
d = list(range(134,173,2))
e = list(range(185,224,2))
f = list(range(241,280,2))
g = list(range(292,311,2))
file_list = a + b + c + d + e + f + g 
tomo_4_4, pauli_vqe, theta = vqe_exp_multi([directory1], file_name='-H2_simulation_echo_2d_sweep_qst.run/', file_list=file_list, init_list=['original'], tomo_modi=False, plot_qst=False, plot_bloch=False, plot_energy=False, plot_error_mitigation=[errors, 'linear'], plot_everything=False)
# Out:
# original
# /content/drive/My Drive/Research/qutip_sim/custom_files/analysis_tools/operation.py:191: RuntimeWarning: divide by zero encountered in true_divide
#   fit = amp*np.exp(-t/decay)*np.sin(2.*np.pi*omega*t+phi)+offset
# /content/drive/My Drive/Research/qutip_sim/custom_files/analysis_tools/operation.py:191: RuntimeWarning: invalid value encountered in true_divide
#   fit = amp*np.exp(-t/decay)*np.sin(2.*np.pi*omega*t+phi)+offset
# /usr/local/lib/python3.6/dist-packages/numpy/fft/_pocketfft.py:77: ComplexWarning: Casting complex values to real discards the imaginary part
#   r = pfi.execute(a, is_real, is_forward, fct)
# /content/drive/My Drive/Research/qutip_sim/custom_files/analysis_tools/operation.py:246: RuntimeWarning: invalid value encountered in double_scalars
#   delta = np.log(r_sig/l_sig)/(2*np.log(p_sig**2/(l_sig*r_sig)))
# Initial state: o
# Data: 1
# original
# Initial state: o
# Data: 2
# original
# Initial state: o
# Data: 3
# original
# ...

# %%
directory1 = '/content/drive/My Drive/Research/Data/Experiment/VQE/VQE_2018/Jun18'
errors = (np.array([1.,2.,4.])*1040. + 480.) / 1520.
a = list(range(34,71,2))
b = list(range(83,122,2))
c = list(range(83,122,2))
d = list(range(134,173,2))
e = list(range(185,224,2))
f = list(range(241,280,2))
g = list(range(292,311,2))
file_list = a + b + c + d + e + f + g 
tomo_4_4, pauli_vqe, theta = vqe_exp_multi([directory1], file_name='-H2_simulation_echo_2d_sweep_qst.run/', file_list=file_list, init_list=['original'], tomo_modi=False, plot_qst=False, plot_bloch=False, plot_energy=False, plot_error_mitigation=[errors, 'linear'], plot_everything=False)
# Out:
# hey (129, 16, 31, 3)
# original
# /content/drive/My Drive/Research/qutip_sim/custom_files/analysis_tools/operation.py:191: RuntimeWarning: divide by zero encountered in true_divide
#   fit = amp*np.exp(-t/decay)*np.sin(2.*np.pi*omega*t+phi)+offset
# /content/drive/My Drive/Research/qutip_sim/custom_files/analysis_tools/operation.py:191: RuntimeWarning: invalid value encountered in true_divide
#   fit = amp*np.exp(-t/decay)*np.sin(2.*np.pi*omega*t+phi)+offset
# /usr/local/lib/python3.6/dist-packages/numpy/fft/_pocketfft.py:77: ComplexWarning: Casting complex values to real discards the imaginary part
#   r = pfi.execute(a, is_real, is_forward, fct)
# /content/drive/My Drive/Research/qutip_sim/custom_files/analysis_tools/operation.py:246: RuntimeWarning: invalid value encountered in double_scalars
#   delta = np.log(r_sig/l_sig)/(2*np.log(p_sig**2/(l_sig*r_sig)))
# Initial state: o
# Data: 1
# original
# Initial state: o
# Data: 2
# original
# Initial state: o
# Data: 3
# original
# ...

# %%
 directory1 = '/content/drive/My Drive/Research/Data/Experiment/VQE/VQE_linear/Nov17'

tomo_4_4, pauli_vqe, theta = vqe_exp_multi([directory1], file_name='-echo_vqe_v5.run/', file_list=range(1,2,1), init_list=['-i, +'], tomo_modi=False, plot_qst=True, plot_bloch=False, plot_energy=True, plot_error_mitigation=[np.linspace(1, 4.5, 8), 'linear'], plot_everything=True)
# Out:
# hey (1, 16, 51, 8)
# -i, +
# /usr/local/lib/python3.6/dist-packages/numpy/fft/_pocketfft.py:77: ComplexWarning: Casting complex values to real discards the imaginary part
#   r = pfi.execute(a, is_real, is_forward, fct)
# /content/drive/My Drive/Research/qutip_sim/custom_files/analysis_tools/operation.py:191: RuntimeWarning: divide by zero encountered in true_divide
#   fit = amp*np.exp(-t/decay)*np.sin(2.*np.pi*omega*t+phi)+offset
# /content/drive/My Drive/Research/qutip_sim/custom_files/analysis_tools/operation.py:191: RuntimeWarning: invalid value encountered in true_divide
#   fit = amp*np.exp(-t/decay)*np.sin(2.*np.pi*omega*t+phi)+offset
# /content/drive/My Drive/Research/qutip_sim/custom_files/analysis_tools/operation.py:191: RuntimeWarning: overflow encountered in exp
#   fit = amp*np.exp(-t/decay)*np.sin(2.*np.pi*omega*t+phi)+offset
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/optimize.py:697: RuntimeWarning: invalid value encountered in double_scalars
# ...

# %% [markdown]
# # 2020/11/17, linear, -i,+ (-i,+)

# %%
directory1 = '/content/drive/My Drive/Research/Data/Experiment/VQE/VQE_linear/Nov17'

tomo_4_4, pauli_vqe, theta = vqe_exp_multi([directory1], file_name='-echo_vqe_v5.run/', file_list=range(1,22,1), init_list=['-i, +'], tomo_modi=False, plot_qst=True, plot_bloch=False, plot_energy=True, plot_error_mitigation=[np.linspace(1, 4.5, 8), 'linear'], plot_everything=True)

# %% [markdown]
# # 2020/11/17, linear, -i,+ (+i,-)

# %%
directory1 = '/content/drive/My Drive/Research/Data/Experiment/VQE/VQE_linear/Nov17'

tomo_4_4, pauli_vqe, theta = vqe_exp_multi([directory1], file_name='-echo_vqe_v5.run/', file_list=range(1,22,1), init_list=['+i, -'], tomo_modi=False, plot_qst=True, plot_bloch=False, plot_energy=True, plot_error_mitigation=[np.linspace(1, 4.5, 8), 'linear'], plot_everything=True)
# Out:
# +i, -
# /usr/local/lib/python3.6/dist-packages/numpy/fft/_pocketfft.py:77: ComplexWarning: Casting complex values to real discards the imaginary part
#   r = pfi.execute(a, is_real, is_forward, fct)
# /content/drive/My Drive/Research/qutip_sim/custom_files/analysis_tools/operation.py:191: RuntimeWarning: divide by zero encountered in true_divide
#   fit = amp*np.exp(-t/decay)*np.sin(2.*np.pi*omega*t+phi)+offset
# /content/drive/My Drive/Research/qutip_sim/custom_files/analysis_tools/operation.py:191: RuntimeWarning: invalid value encountered in true_divide
#   fit = amp*np.exp(-t/decay)*np.sin(2.*np.pi*omega*t+phi)+offset
# /content/drive/My Drive/Research/qutip_sim/custom_files/analysis_tools/operation.py:191: RuntimeWarning: overflow encountered in exp
#   fit = amp*np.exp(-t/decay)*np.sin(2.*np.pi*omega*t+phi)+offset
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/optimize.py:697: RuntimeWarning: invalid value encountered in double_scalars
# ...

# %% [markdown]
# # 2020/11/17, exponential

# %%
directory1 = '/content/drive/My Drive/Research/Data/Experiment/VQE/VQE_expo/Nov17'

tomo_4_4, pauli_vqe, theta = vqe_exp_multi([directory1], file_name='-echo_vqe_v5.run/', file_list=range(1,8,1), init_list=['-i, +'], tomo_modi=False, plot_qst=True, plot_bloch=False, plot_energy=True, plot_error_mitigation=[np.logspace(0, 4, 5, base=2), 'exponential'], plot_everything=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-759d4a4617b7> in <module>()
#       1 directory1 = '/content/drive/My Drive/Research/Data/Experiment/VQE/VQE_expo/Nov17'
#       2
# ----> 3 tomo_4_4, pauli_vqe, theta = vqe_exp_multi([directory1], file_name='-echo_vqe_v5.run/', file_list=range(1,8,1), init_list=['-i, +'], tomo_modi=False, plot_qst=True, plot_bloch=False, plot_energy=True, plot_error_mitigation=[np.logspace(0, 4, 5, base=2), 'exponential'], plot_everything=True)
#
# /content/drive/My Drive/Research/qutip_sim/custom_files/analysis_tools/experiment_analysis.py in vqe_exp_multi(directories, file_name, file_list, init_list, offset, tomo_modi, plot_qst, plot_bloch, plot_energy, plot_error_mitigation, plot_everything)
#     295     pauli_vqes = []
#     296     for i, directory in enumerate(directories):
# ...

# %% [markdown]
# # 2020/11/18, linear

# %%
directory1 = '/content/drive/My Drive/Research/Data/Experiment/VQE/VQE_linear/Nov18'

tomo_4_4, pauli_vqe, theta = vqe_exp_multi([directory1], file_name='-echo_vqe_v5.run/', file_list=range(1,8,1), init_list=['-i, +'], tomo_modi=False, plot_qst=True, plot_bloch=False, plot_energy=True, plot_error_mitigation=[np.linspace(1, 4.5, 8), 'linear'], plot_everything=True)
