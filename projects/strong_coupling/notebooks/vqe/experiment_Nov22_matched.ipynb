# %%
import os, sys, importlib
import copy
sys.path.append('/content/drive/My Drive/Research/qutip_sim/custom_files')
sys.path.append('/content/drive/My Drive/Research/qutip_sim/custom_files/VQE_files')
sys.path.append('/content/drive/My Drive/Research/qutip_sim/site-packages')
sys.path.append('/content/drive/My Drive/Research/qutip_sim/site-packages/qutip')
from H2Functions import read_in_data
from qutip import *
# !pip install scikit-optimize
from analysis_tools import *
from sim_functions import *
from experiment_sim import *

import matplotlib.pyplot as plt
import numpy as np
from scipy import optimize
# %load_ext autoreload 
# %autoreload 2
label = ["II", "IX", "IY", "IZ", "XI", "XX", "XY", "XZ", "YI", "YX", "YY", "YZ", "ZI", "ZX", "ZY", "ZZ"]
# Out:
# ...
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Test

# %%
for i in range(1,10,2):
  print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# # Result of exponential

# %%
directory1 = '/content/drive/My Drive/Research/Data/Experiment/VQE/VQE_modified_tomography/Nov22/pim'
directory2 = '/content/drive/My Drive/Research/Data/Experiment/VQE/VQE_modified_tomography/Nov22/mip'
directory3 = '/content/drive/My Drive/Research/Data/Experiment/VQE/VQE_modified_tomography/Nov22/mmi'
directory4 = '/content/drive/My Drive/Research/Data/Experiment/VQE/VQE_modified_tomography/Nov22/ppi'
tomo_4_4, pauli_vqe, theta = vqe_exp_multi([directory1, directory2, directory3, directory4], file_name='-echo_vqe_v5.run/', file_list=range(2,11,2), init_list=['+i, -','-i, +','-, -i','+, +i'], tomo_modi=True, plot_qst=True, plot_bloch=True, plot_energy=True, plot_error_mitigation=[np.linspace(1, 60, 21), 'exponential'], plot_everything=True)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Result of linear

# %%
directory1 = '/content/drive/My Drive/Research/Data/Experiment/VQE/VQE_modified_tomography/Nov22/pim'
directory2 = '/content/drive/My Drive/Research/Data/Experiment/VQE/VQE_modified_tomography/Nov22/mip'
directory3 = '/content/drive/My Drive/Research/Data/Experiment/VQE/VQE_modified_tomography/Nov22/mmi'
directory4 = '/content/drive/My Drive/Research/Data/Experiment/VQE/VQE_modified_tomography/Nov22/ppi'
tomo_4_4, pauli_vqe, theta = vqe_exp_multi([directory1, directory2, directory3, directory4], file_name='-echo_vqe_v5.run/', file_list=range(1,10,2), init_list=['+i, -','-i, +','-, -i','+, +i'], tomo_modi=True, plot_qst=True, plot_bloch=True, plot_energy=True, plot_error_mitigation=[np.linspace(1, 4.5, 8), 'linear'], plot_everything=True)
# Out:
# +i, -
# /usr/local/lib/python3.6/dist-packages/numpy/fft/_pocketfft.py:77: ComplexWarning: Casting complex values to real discards the imaginary part
#   r = pfi.execute(a, is_real, is_forward, fct)
# /content/drive/My Drive/Research/qutip_sim/custom_files/analysis_tools/operation.py:191: RuntimeWarning: divide by zero encountered in true_divide
#   fit = amp*np.exp(-t/decay)*np.sin(2.*np.pi*omega*t+phi)+offset
# /content/drive/My Drive/Research/qutip_sim/custom_files/analysis_tools/operation.py:191: RuntimeWarning: invalid value encountered in true_divide
#   fit = amp*np.exp(-t/decay)*np.sin(2.*np.pi*omega*t+phi)+offset
# Initial state: +
# Data: 1
# Data: 1 QST
# Data: 1 Energy curve
# +i, -
# /content/drive/My Drive/Research/qutip_sim/custom_files/analysis_tools/operation.py:191: RuntimeWarning: overflow encountered in exp
#   fit = amp*np.exp(-t/decay)*np.sin(2.*np.pi*omega*t+phi)+offset
# ...

# %%
directory1 = '/content/drive/My Drive/Research/Data/Experiment/VQE/VQE_modified_tomography/Nov22/pim'
directory2 = '/content/drive/My Drive/Research/Data/Experiment/VQE/VQE_modified_tomography/Nov22/mip'
directory3 = '/content/drive/My Drive/Research/Data/Experiment/VQE/VQE_modified_tomography/Nov22/mmi'
directory4 = '/content/drive/My Drive/Research/Data/Experiment/VQE/VQE_modified_tomography/Nov22/ppi'
tomo_4_4, pauli_vqe, theta = vqe_exp_multi([directory1, directory2, directory3, directory4], file_name='-echo_vqe_v5.run/', file_list=range(1,7,2), init_list=['+i, -','-i, +','-, -i','+, +i'], tomo_modi=True, plot_qst=True, plot_bloch=True, plot_energy=True, plot_error_mitigation=[np.linspace(1, 4.5, 8), 'linear'], plot_everything=True)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Nov.22 Test of matched tomography pulse

# %%
directory1 = '/content/drive/My Drive/Research/Data/Experiment/VQE/VQE_modified_tomography/Nov21/pim'
directory2 = '/content/drive/My Drive/Research/Data/Experiment/VQE/VQE_modified_tomography/Nov21/mip'
tomo_4_4, pauli_vqe, theta = vqe_exp_multi([directory1, directory2], file_name='-echo_vqe_v5.run/', file_list=range(1,3,1), init_list=['+i, -','-i, +'], plot_qst=True, plot_bloch=True, plot_energy=True, plot_error_mitigation=[np.linspace(1, 4.5, 8), 'linear'], plot_everything=True) # [52, 144, 190, 236]
# Out:
# Output hidden; open in https://colab.research.google.com to view.
